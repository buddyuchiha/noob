# %% [markdown]
# __КАК ПОДКЛЮЧИТЬ POSTGRESQL в DJANGO__

# %% [markdown]
# 1) Заходим и авторизируемся в SQL SHELL:
#
# ![image.png](attachment:image.png)
#
# 2) Создаем БД:
#
# ![image-2.png](attachment:image-2.png)
#
# 3) Проверим нашу БД:
#
# ![image-3.png](attachment:image-3.png)
#
# 4) Создаем пользователя:
#
# ![image-4.png](attachment:image-4.png)
#
# 5) Даем пользователю возможность входа:
#
# ![image-5.png](attachment:image-5.png)
#
# 6) Даем пользователю все привелегии для работы с БД:
#
# ![image-6.png](attachment:image-6.png)
#
# 7) Даем возможность пользователю для создания базы данных:
#
# ![image-7.png](attachment:image-7.png)
#
# 8) Подключаемся к БД:
#
# ![image-8.png](attachment:image-8.png)
#
# 9) Теперь нужно дать доступ к схеме public (чтоб не было ошибок миграции):
#
# ![image-9.png](attachment:image-9.png)
#
# 10) Настроим Postgres в самом Django, установив в проект модуль:
#
# ![image-10.png](attachment:image-10.png)
#
# 11) Настроим settings.py
#
# ![image-11.png](attachment:image-11.png)
