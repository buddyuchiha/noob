# %% [markdown]
# __#4. Маршрутизация и функции представления__

# %% [markdown]
# В файле приложения women view.py пропишем свое представление, которое будет формировать внешний вид главной страницы сайта.
#
# Представления можно реализовать в виде функций или классов:
#
# ![image.png](attachment:image.png)
#
# request это ссылка на специальный класс HttpRequest, который содержит информацию о запросах (сессии, куки)
#
# HttpResponse - ответ на запрос (необходимо его импортировать)

# %% [markdown]
# нужно связать эту функцию с соответсующим URL-адресом для этого необходимо:
#
# 1) перейти в главную папку
# 2) открыть urls.py
# 3) добавить маршрут в urlpatterns через path: ![image.png](attachment:image.png)
#
# где первый параметр отпределяет суффкис URL-адреса, а второй ссылка на функцию представления

# %% [markdown]
# как только мы добавим хотя бы один маршрут - тестовая главная страница станет недоступна, если же мы хотим оставить эту страницу, то в urlpatterns нужно добавить путь с пустой строкой (+ более удобный импорт):
#
# ![image.png](attachment:image.png)

# %% [markdown]
# подход записи маршрутов в файле конфигурации нарушает принцип независимости приложений, это фиксится возможностью, которую предоставляет Django:
#
# вторым аргументом в path прописать спец функцию include, используя которую можно подключить все необходимые маршруты:
# ![image-2.png](attachment:image-2.png)
#
# аргумент include - файлы, в котором должны быть прописаны приложения (urls.py - мы его создаем сами в папке приложения), они как раз содержат пути: ![image.png](attachment:image.png)

# %% [markdown]
# также можно добавить в изначальные пути прфекси, чтоб он применился ко всем маршрутам include:
#
# ![image.png](attachment:image.png)
