# %% [markdown]
# __#27. Отображение постов по рубрикам__

# %% [markdown]
# 1) Обновим путь:
#
# ![image.png](attachment:image.png)
#
# 2) Изменим представление:
#
# ![image-2.png](attachment:image-2.png)
#
# ![image-3.png](attachment:image-3.png)
#
# ![image-4.png](attachment:image-4.png)
