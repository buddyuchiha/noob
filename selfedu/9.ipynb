# %% [markdown]
# __#9. Шаблоны, начало. Функции render() и render to string()__

# %% [markdown]
# Шаблон в Django - это механизм для генерации HTML (или других текстовых форматов) с динамическими данными. Они позволяют отделить логику Python-кода от визуального представления.
#
# Самый напипростейший способ использования шаблона в Django - функция render_to_string, которая принимает путь к шаблону:
#
# ![image-3.png](attachment:image-3.png)
#
# По умолчанию Django ищет шаблоны в подкаталоге templates нашего приолжения -> его необходимо создать:
#
# ![image-2.png](attachment:image-2.png)
#
# Необязательно в пути прописывать подкаталог templates и так далее, так как Django сам знает где че искать (крутяк), НО!
#
# -> чтобы не возникало коллизий (так как Django не будет разбираться какой index в каком templates он просто выберет самвый первый) необходимо в папке templates создать подпапку women (с названием приложения) и уже туда закинуть шаблон + указать другой путь:
#
# ![image.png](attachment:image.png)
#
# Кодировка шаблона должна быть UTF-8

# %% [markdown]
# Для объединения этих двух строчек:
#
# ![image.png](attachment:image.png)
#
# можно использовать функцию render
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# Конфигурация шаблонов в джанго:
#
# ![image.png](attachment:image.png)
#
# DIRS позволяет прописывать нестандартные пути к файлам-шаблонам
#
# APP_DIRS говорит, что шаблоны нужно искать в подкаталоге templates

# %% [markdown]
# Чтобы шаблоны отображались, нужно чтобы приложение, которое их хранит было записано в:
#
# ![image.png](attachment:image.png)
#
# или же явно указать путь в DIRS
