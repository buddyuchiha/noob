# %% [markdown]
# __#25. Создание связи many-to-one многие к одному (ForeignKey)__

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Многие - категории (первичная модель)
#
# Один - пост (вторичная модель)
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Определим класс категорий:
#
# ![image.png](attachment:image.png)
#
# Теперь этот класс категорий нужно связать с классом вумен с помощью __ForeignKey__
#
# 1) Объявим поле для ключа в классе:
#
# ![image-5.png](attachment:image-5.png)
#
# обязательно нужно указывать параметр on_delete, protect - функция, которая при попытке удалении связанной категории, будет запрещать удаление,  null разрешает нулевые значения
#
# 2) Создаем файл миграции:
#
# ![image-2.png](attachment:image-2.png)
#
# 3) Применяем эту миграцию:
#
# ![image-3.png](attachment:image-3.png)
#
# 4) Получаем:
#
# ![image-4.png](attachment:image-4.png)
#
# 5) Открываем оболочку Django (shell plus):
#
# ![image-6.png](attachment:image-6.png)
#
# 6) Добавляем новые записи:
#
# ![image-7.png](attachment:image-7.png)
#
# 7) В таблице с женщинами присвоим cat_id значение:
#
# ![image-8.png](attachment:image-8.png)
#
# 8) Убираем значение NULL=true:
#
# ![image-9.png](attachment:image-9.png)
#
# 9) Создаем файл миграции и выбираем пункт 2:
#
# ![image-10.png](attachment:image-10.png)
#
# 10) Создаем миграции:
#
# ![image-11.png](attachment:image-11.png)

# %% [markdown]
# Теперь в модели Women создан внешний ключ cat, который ссылается на конкретную запись из модели категории
#
# Отличие между cat и cat_id:
#
# cat - полноценный объект класса категории с двумя полями (в нашем случае name и slug)
#
# ![image.png](attachment:image.png)
