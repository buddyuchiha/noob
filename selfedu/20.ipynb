# %% [markdown]
# __#20. Методы выбора записей из таблиц.__

# %% [markdown]
# Используя shell plus можно сразу создавать записи:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Для красивой и хорошой отладки, можно определить в классе след маг. метод:
#
# ![image.png](attachment:image.png)
#
# Который позволит при выводе сразу видеть что за объект:
#
# ![image-2.png](attachment:image-2.png)
#
# Для отображения одного или нескольких конкретных элементов:
#
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# Так можно фильтровать:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# У ORM Django есть люкапы:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Пример использования:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Также можно прописывать несколько условий:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# exclude работает противоположно к методу filter
#
# ![image.png](attachment:image.png)

# %% [markdown]
# get всегда возвращает только одну запись
#
# и он еще генерирут исключения
#
# ![image.png](attachment:image.png)
