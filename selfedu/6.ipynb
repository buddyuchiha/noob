# %% [markdown]
# __#6. Динамические URL. Пользовательские конвертеры__

# %% [markdown]
# В маршрутизации можно добавлять конверторвы следующим образом:
# 1) ![image.png](attachment:image.png)
# 2) ![image-2.png](attachment:image-2.png)
# 3) ![image-3.png](attachment:image-3.png)

# %% [markdown]
# Согласно документации возможны следующие типы данных в конверторах:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# slug позволяет конвертировать любые аски симолвы:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# маршруты ищутся сверху вниз по очереди
#
# если же по каким-ибо причинами дефолтных конверторов недостаточно, то в Django есть функция: __re_path()__
#
# 1) ![image-2.png](attachment:image-2.png)
# 2) ![image.png](attachment:image.png)
# 3) ![image-3.png](attachment:image-3.png)

# %% [markdown]
# Фреймворк Django позволяет создавать свои собсвтенные конверторы, используемые для анализы URL-адресов, для этого:
#
# 1) Создаем файл converters.py в папке приложения women
# 2) Добавляем туда шаблон/пишем свой конвертер
# 3) Переходим обратно в пути urls приложения women и импортируем его
# 4) Регистрируем конвертер, используя след. функцию:
#
# ![image.png](attachment:image.png)
#
# 5) Устанавливаем маршрутизацию
#
# ![image-3.png](attachment:image-3.png)
