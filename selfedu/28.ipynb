# %% [markdown]
# __#28. Добавляем связь many-to-many (многие ко многим)__

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Определим модель тегов:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Свяжем ее с основным модулем:
#
# ![image-2.png](attachment:image-2.png)
#
# Сделаем миграции:
#
# ![image-3.png](attachment:image-3.png)
#
# Перейдем в оболочку и создадим тэги:
#
# ![image.png](attachment:image.png)
#
# Применим их к women_women
#
# 1) Создаем объект для записи (ну тип берем какую-либо девушку):
#
# ![image-4.png](attachment:image-4.png)
#
# 2) Создаем объекты тегов:
#
# ![image-5.png](attachment:image-5.png)
#
# 3) Привязываем их к девушке:
#
# ![image-6.png](attachment:image-6.png)
#
# ![image-7.png](attachment:image-7.png)

# %% [markdown]
# Для удаления:
#
# ![image.png](attachment:image.png)
#
# Для добавления:
#
# ![image-2.png](attachment:image-2.png)
#
# Для получения списка всех тэгов:
#
# ![image-3.png](attachment:image-3.png)
