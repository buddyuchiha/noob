# %% [markdown]
# __#14. Наследование шаблонов (extends). Тег include__

# %% [markdown]
# Согласно паттерну DRY (don't repeat yourself) в Django создается базовый общий шаблон, а потом этот шаблон наследуется.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Базовый шаблон создается на уровне всего проекта (в главной папке крч)
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Как все устроено:
#
# 1) Создам свой путь к папке с базовым шаблоном:
#
# ![image.png](attachment:image.png)
#
# 2) Прописываем base.html используя тэг block content:
#
# ![image-2.png](attachment:image-2.png)
#
# 3) Меняем наши остальные файлы, наследуя базовый через тэг extends:
#
# ![image-3.png](attachment:image-3.png)
#
# ![image-4.png](attachment:image-4.png)

# %% [markdown]
# Тэг include позволяет добавить какой либо шаблон в файл, например если мы хоти навигацию для всех реализовать:
#
# 1) создам папку и файл
#
# ![image.png](attachment:image.png)
#
# 2) подключаем все к желаемому файлу
#
# ![image-2.png](attachment:image-2.png)
#
# используя тэг only может запретить передачу переменных
#
# при расширении шаблона, все, что в дочернем, доступно и в базовом
