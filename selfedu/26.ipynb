# %% [markdown]
# __#26. ORM-команды для связи many-to-one__

# %% [markdown]
# Как через один объект получить все категории связаные с одной определенной:
#
# ![image-2.png](attachment:image-2.png)
#
# у объекта автоматически формируется следующий атрибут:
#
# ![image.png](attachment:image.png)
#
# как он выглядит:
#
# ![image-3.png](attachment:image-3.png)
#
# увидев, что это менеджер делаем вывод, что можно значит и вывести все:
#
# ![image-4.png](attachment:image-4.png)

# %% [markdown]
# Можем указать заранее название этого атрибута:
#
# ![image.png](attachment:image.png)
#
# И выводить все так:
#
# ![image-2.png](attachment:image-2.png)
