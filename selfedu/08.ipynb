# %% [markdown]
# __#8. Перенаправления (redirect). Функция reverse__

# %% [markdown]
# Очень часто при развертывании сайта некоторые его страницы переносятся на другой URL-адрес, чтоб не потерять позиции этих страниц, поисковым системам нужно явно указать, что страница перенесена либо временно, либо навсегда:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
#
# редирект по умолчанию делают перенаправление с таким вот кодом:
#
# ![image-2.png](attachment:image-2.png)
#
# для перенаправления с кодом 301 нужно:
#
# ![image-3.png](attachment:image-3.png)
#
# и получаем код:
#
# ![image-4.png](attachment:image-4.png)

# %% [markdown]
# также в качестве аргумента в redirect можно указывать функции представления:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# и имя маршрута (рекомендуемая практика):
#
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# Еще можно передавать значения:
#
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)
#
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# также (не знаю зач) можно через функцию из django.urls reverse:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# помимо функцию редирект джанго располагает классами, которые можно использовать вместо редирект:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# из этого можно вроде использовать че по кайфу, но редирект более гибкая (вроде)
