# %% [markdown]
# __#10. Передача данных (переменных) в шаблоны__

# %% [markdown]
# Чтобы на каждой странице HTML был свой заголовок, переданной ей через параметр title надо:
#
# 1) Прописать параметр title: ![image.png](attachment:image.png)
#
# 2) Реализовать логику в функциях: ![image-2.png](attachment:image-2.png)

# %% [markdown]
# В шаблоны если чо можно передавать разные типы данных, для примера разберем список:
#
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)
#
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# Шаблонизатор Django __НЕ__ поддерживает обращение по индексу:
#
# ![image.png](attachment:image.png)
#
# Обращаться можно через точку к ключу или индексу:
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# Внутри фигурных скобок можно отображать только одну какую-либо переменную
