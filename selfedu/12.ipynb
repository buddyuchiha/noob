# %% [markdown]
# __#12. Теги шаблонов. Теги if и for__

# %% [markdown]
# Помимо фильтров в шаблонах можно прописывать специальные теги
#
# Тег записывается в след виде:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Возьмем некий набор данных:
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# Определим тег for в шаблоне (он обязательно должен начинаться и заканчиваться enfor)
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Результат:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# по сути тэг for представляется как:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Тэг if подобен оператору if языка python, главное также в конце указать endif
#
# ![image-4.png](attachment:image-4.png)
#
# переменная forloop появляется только если у нас есть тэг for
#
# результат:
#
# ![image-5.png](attachment:image-5.png)
