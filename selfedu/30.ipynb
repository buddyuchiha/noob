# %% [markdown]
# __#30. Связь one-to-one (один к одному)__

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Создадим еще один класс:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Добавляем новое поле в модель:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Создам миграцию и т.п
