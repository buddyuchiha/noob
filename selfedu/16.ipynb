# %% [markdown]
# __#16. Пользовательские теги шаблонов. Декораторы simple_tag и inclusion_tag__

# %% [markdown]
# Все пользовательские тэги должны размещаться в каталоге templatetags + в файле должен быть init
#
# Просто пример как его регнуть:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Регаем его в шаблоне и используем:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Пример:
#
# ![image.png](attachment:image.png)
