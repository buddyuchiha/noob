# %% [markdown]
# __#37. Подключение админ-панели. Регистрация моделей__

# %% [markdown]
# Вызов админ панели:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Устанавливаем русский язык:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Админка помогает нам создавать пользователя с разными привелегиями, отображать все наши приложения, добавлять и удалять изменения записей.
#
# Сначала необходимо создать суперпользователя:
#
# ![image.png](attachment:image.png)
#
# Регаем наше приложение в файле приложения admin.py:
#
# ![image-2.png](attachment:image-2.png)
#
# Видим ништяки:
#
# ![image-3.png](attachment:image-3.png)
