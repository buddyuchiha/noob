# %% [markdown]
# __#51. Введение в CBV (Class Based Views). Классы View и TemplateView__

# %% [markdown]
# Представления на практике регают в виде классов
#
# Базовый класс View:
#
# ![image.png](attachment:image.png)
#
# Начнем описывать класс AddPage:
#
# ![image-2.png](attachment:image-2.png)
#
# Свяжем путь:
#
# ![image-3.png](attachment:image-3.png)
