# %% [markdown]
# __#13. Шаблонный тег url__

# %% [markdown]
# как прописываются ссылку в HTML документе:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Можно динамически формировать URL-адреса, используя названия URL-шаблонов
#
# 1) Объявим путь:
#
# ![image.png](attachment:image.png)
#
# 2) Пропишем функцию:
#
# ![image-2.png](attachment:image-2.png)
#
# 3) Применим шаблонный тег URL:
#
# ![image-3.png](attachment:image-3.png)
#
# к index.html:
#
# ![image-4.png](attachment:image-4.png)

# %% [markdown]
# Это тег работает аналогично функции Django __reverse__

# %% [markdown]
# Теперь пример как можно сделять менюшку:
#
# 1) Пропишем пути:
#
# ![image.png](attachment:image.png)
#
# 2) Объявим представления:
#
# ![image-2.png](attachment:image-2.png)
#
# 3) Создадим словарь для удобной работы по ключам:
#
# ![image-3.png](attachment:image-3.png)
#
# 4) Свяжем все в index.html через тэг for, if и url:
#
# ![image-4.png](attachment:image-4.png)
#
# Результат:
#
# ![image-5.png](attachment:image-5.png)
