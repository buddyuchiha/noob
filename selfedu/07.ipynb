# %% [markdown]
# __#7. GET- и POST-запросы. Обработчики исключений запросов__

# %% [markdown]
# Структура URL адреса может содержать дополнительные параметры в GET-запросах.
#
# Структура GET-запроса:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Для выделения пар ключ-значение на стороне сервера как раз используется параметр request в представлениях:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# в частоности, у него есть следующий словарик, который можно вывести:
#
# ![image.png](attachment:image.png)
#
# при запросе http://127.0.0.1:8000/cats/music/?name=Gagarina&type=pop
#
# будет вывод:
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# можно также сделать условия для проверки получения:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Помимо GET-запросов еще часто используются POST-запросы, они связаны с передачей данных из форм. В этом случае вместо request.GET -> request.POST

# %% [markdown]
# Самым базовым исключение является обращение к несуществующей страничке сайта, в Django при таком обращении мы видим при DEBUG = True:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# если его отключить, то у нас будет ошибка, так как наш локальный хост не будет указан в ALLOWED_HOSTS (разрешенных хостах), поэтому его нужно указать:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# чтобы мы могли обрабатывать такие ошибки - нам необходимо перейти в пути главной папки и указать специальный обработчик __handler404__
#
# ![image-2.png](attachment:image-2.png)
#
# который будет равен функции, заданной в  views.py

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Результат:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Теперь если в какой-либо функции из представлений views.py мы сгенерируем исключение 404 - оно будет сразу переброшено в handler404:
#
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# Есть еще handler400, handler403, handler500 и т.п которые мы также можем реализовать
#
# Главное помнить, что дебаг должен быть оффнут
