# %% [markdown]
# __#15. Подключение статических файлов__

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
#
# это команда собирает все файлы в указанный каталог

# %% [markdown]
# чтоб все корректно работало необходимо определить:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# проверяем что все есть в settings, затем создаем папки с путями:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Подключаем все:
#
# ![image.png](attachment:image.png)
