# %% [markdown]
# __#43. Что такое HTML-формы. Отправка данных по GET и POST-запросам__

# %% [markdown]
# Форма создаются специальным тегом:
#
# ![image.png](attachment:image.png)
#
# и служат для передачи на сервер пользоватльеской информации
#
# В Django можно создать формы, связанные с моделью (БД) и формы, не связанные с моделью (БД)
#
# 1) Регаем функцию:
#
# ![image-2.png](attachment:image-2.png)
#
# 2) Делам html форму
#
# ![image-3.png](attachment:image-3.png)
#
# Результат:
#
# ![image-4.png](attachment:image-4.png)
#
# Для передачи данных на сервер используется POST запрос
