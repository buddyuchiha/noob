# %% [markdown]
# __#19. Понятие CRUD. Добавление записей в таблицу БД. Модуль django-extensions__

# %% [markdown]
# CRUD (Create Read Update Delete)
#
# Все проекты, построенные на Django используют ORM не переходя на уровень SQL-запросов, так как в этом по сути нет необходимости:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Объекта класса - набор записей
#
# ![image-3.png](attachment:image-3.png)
#
# Откроем оболочкц фреймворка Django:
#
# ![image.png](attachment:image.png)
#
# Импортируем модель:
#
# ![image-2.png](attachment:image-2.png)
#
# Создаем новый объект:
#
# ![image-4.png](attachment:image-4.png)
#
# Модели в Django являются "ленивыми", то есть создание объекта класса еще не означает фактическое добавление записи в таблицу
#
# Привяжем переменную к последнему созданному объекту:
#
# ![image-5.png](attachment:image-5.png)
#
# Сохраним запись:
#
# ![image-6.png](attachment:image-6.png)
#
# Результат:
#
# ![image-7.png](attachment:image-7.png)

# %% [markdown]
# Также можно глянуть данные через оболочку:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Вместой id в Django часто используют pk:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Также можно сначала создать объект, а потом наполнять его данными:
#
# ![image.png](attachment:image.png)
#
# А это норм плюшка с расширениями для удобной работы с оболочкой:
#
# ![image-2.png](attachment:image-2.png)
#
# Ее также нужно добавить:
#
# ![image-4.png](attachment:image-4.png)
#
# Ну и использовать:
#
# ![image-3.png](attachment:image-3.png)
