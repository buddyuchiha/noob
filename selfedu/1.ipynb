# %% [markdown]
# __#1. Django, что это такое? Инструментальные средства__

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# WSGI (Web Server Gateway Interface) - стандарт взаимодействия между Python программой, выполняющейся на стороне сервера, и самим веб-сервером.
#
# Пакет Django содержит отладочный веб-сервер, который можно запустить на домашнем ПК.
#
# Для работы с файлами нормалек Far manager
