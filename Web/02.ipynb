# %% [markdown]
# __Что такое Rest API (http)? Soap? GraphQL? Websockets? RPC (gRPC, tRPC). Клиент - сервер. Вся теория__

# %% [markdown]
# Способы общения клиента и сервера
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Клиентом может быть сервер, приложение и браузер:
#
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# Первоначальная идея HTTP обмен HTML-доков, но теперь передаются тексты, файлы и json'ы
#
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# __REST API__
#
# Архитектурный стиль, который сообщает как наиболее эффективно общаться клиенту и серверу про протоколу HTTP (набор правил)
#
# 1) Первая концепция
#
# ![image.png](attachment:image.png)
#
# 2) Вторая концепция:
#
# ![image-2.png](attachment:image-2.png)
#
# 3) Третья концепция:
#
# ![image-3.png](attachment:image-3.png)
#
# Иными словами: каждый раз клиент и сервер общаются как в первый раз
#
# 4) Четвертая концепция:
#
# ![image-4.png](attachment:image-4.png)
#
# Например CRUD-операция:
#
# ![image-5.png](attachment:image-5.png)
#
# ![image-6.png](attachment:image-6.png)
#
# 5) Пятая концепция:
#
# ![image-7.png](attachment:image-7.png)
#
# Стоит учитывать, что:
#
# ![image-8.png](attachment:image-8.png)
#
# Формат обмена данными в большинстве случаев JSON, иногда XML
#
# Также важно версирвировать апишку и документировать
#
# OpenAPI - спецификация, которая может помочь задокументировать апишку
#
# Swagger - набор инструментов уже для теста различных эндпоинтов и кнопок

# %% [markdown]
# __SOAP__
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Если REST - множество окон, то SOAP одно больше окно со строгими рамками и строгой структурой

# %% [markdown]
# __GraphQL__ -
#
# это язык запросов
#
# ![image.png](attachment:image.png)
#
# Два оснонвых вида запроса:
#
# QUERY[GET]
#
# MUTATION[POST]
#
# Есть еще SUBSCRIPTION - real time изменения

# %% [markdown]
# 1) Сначала описывается схема данных:
#
# ![image.png](attachment:image.png)
#
# 2) Затем запросы данных:
#
# ![image-2.png](attachment:image-2.png)
#
# 3) Часто запрашиваемы данные можно вывести во фрагменты:
#
# ![image-3.png](attachment:image-3.png)
#
# 4) Мутации как-то изменяют данные:
#
# ![image-4.png](attachment:image-4.png)

# %% [markdown]
# __Websockets__ - протокол для real-time изменений (онлайн-чаты, биржы и т.п)

# %% [markdown]
# __RPC__ -
#
# удаленный вызов процедур
#
# ![image.png](attachment:image.png)
#
# клиент ощущает будто бы он сам вызывает процедуры удаленно
#
# __GRPC__ -
#
# фреймворк/набор инструментов
#
# популерн для микросервисной архитектуры
#
# ![image-2.png](attachment:image-2.png)
