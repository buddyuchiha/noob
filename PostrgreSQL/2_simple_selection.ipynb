# %% [markdown]
# ![image.png](attachment:image.png)
#
# чтоб скачать данные с SQL - нужно прожать экспорт данных

# %% [markdown]
# чтоб выбрать конкретные столбцы
#
# ![image.png](attachment:image.png)

# %% [markdown]
# distinct используется для извлечения уникальных значений из базы данных
#
# можно и по двум извлекать и так далее
#
# ![image.png](attachment:image.png)

# %% [markdown]
# для сортировки используется order by
#
# ![image.png](attachment:image.png)

# %% [markdown]
# для сортировки с условием
#
# ![image-2.png](attachment:image-2.png)
#
# ну и так крч через условные оператора и and/or in/not in можно все сортировать
#
# ![image.png](attachment:image.png)

# %% [markdown]
# также можно использовать between
#
# ![image.png](attachment:image.png)

# %% [markdown]
# знак % означает, что мы ищем любое количество символов и подсимволов, допустим любые символы и любое их количество перед %Silver% и после
#
# для чилсенных строк
#
# ![image.png](attachment:image.png)

# %% [markdown]
# _ означает любой один символ

# %% [markdown]
# ilike - содержит подструку
#
# когда у нас несколько условий рекомендуется в начале после where написать 1 = 1
#
# делается, чтобы потом было проще редактировать скрипт
#
# ![image.png](attachment:image.png)
