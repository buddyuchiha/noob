# %% [markdown]
# __Группировка__

# %% [markdown]
# Помогает сгруппировать данные и допустим найти общее количество продаж или же количество клиентов с определенными характеристиками.

# %% [markdown]
# Как посчитать кол-во строк
#
# ![image.png](attachment:image.png)
#
# звездочка означает строку

# %% [markdown]
# Пример подсчета кол-ва уникальных элементов
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Пример подсчета максимума и минимума
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Группировка GROUP BY
#
# позволяет нам получить уникальные значения по столбцу/n-столбцам и применить к каждому паре агрегирующую операцию

# %% [markdown]
# Пример использования
#
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# Также можно комбинировать и считать количество
#
# ![image.png](attachment:image.png)

# %% [markdown]
# И суммировать
#
# ![image.png](attachment:image.png)

# %% [markdown]
# с условиями
#
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)
