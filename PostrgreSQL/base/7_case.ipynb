# %% [markdown]
# __Условный оператор Case__

# %% [markdown]
# CASE - условный оператор, который позволяет осуществовлять проверку и возвращать результат, который зависит от того, какие условие выполнено.
#
# Аналог "Если" в Excel.

# %% [markdown]
# Пример обычного использования case
#
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# Также можно фильтровать или делать более глобальные условия
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Также можно использовать GROUP BY
#
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# Пример использования с агрегатной функцией
#
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)
