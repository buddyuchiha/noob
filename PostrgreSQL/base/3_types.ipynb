# %% [markdown]
# __Типы данных__

# %% [markdown]
# Основные это:
#
# character (строка символов)
#
# numbers (числа)
#
# data и время
#
# у одного столбца таблицы может быть только один определенный тип данных

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Стандарный тип данных означает, что в любой СУБД есть такой тип данных

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Чтобы ввести данные в таблицу:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Смотрим результат:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Записываем в csv файл резы
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Вот кстати и результат того, что мы написали более короткое значение в строку, чем указывали
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Тип данных text создан для удобства

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Создадим таблицу
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Вставим туда данные
#
# ![image.png](attachment:image.png)
#
# default означает, что будет использоваться значение по умолчанию (для проверки serial)

# %% [markdown]
# Добавим вторую строку и увидим, как работает serial
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# Создадим и заполним таблицу
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# Результат
#
# ![image.png](attachment:image.png)
#
# некоторые значения округлились

# %% [markdown]
# Умножим значения
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Результат разный, так как разные типы десятичных чисел
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
#
# time zone означает, что будет в строке временная метка

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Чтоб посмотреть все способы задать часовой пояс
#
# ![image-2.png](attachment:image-2.png)
